# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %matplotlib inline

 # Different encoding to read brazilian data
mp = pd.read_csv("Focos_2022-10-17_2022-10-18.csv", encoding='LATIN1')

mp.head()
# Out:
#               datahora satelite    pais estado     municipio     bioma  \
# 0  2022/10/22 00:05:14  GOES-16  Brasil   PARA  MONTE ALEGRE  Amazonia
# 1  2022/10/22 00:05:14  GOES-16  Brasil   PARA  MONTE ALEGRE  Amazonia
# 2  2022/10/22 00:05:18  GOES-16  Brasil   PARA  MONTE ALEGRE  Amazonia
# 3  2022/10/22 00:05:18  GOES-16  Brasil   PARA  MONTE ALEGRE  Amazonia
# 4  2022/10/22 00:05:18  GOES-16  Brasil   PARA  MONTE ALEGRE  Amazonia
#
#    diasemchuva  precipitacao  riscofogo  latitude  longitude   frp
# 0          2.0          8.14       0.03   -1.4215   -53.9763  67.4
# 1          2.0          8.09       0.28   -1.4398   -53.9761  42.0
# 2          3.0          0.13       0.68   -2.1361   -54.4471  51.1
# 3          3.0          0.20       0.60   -2.1362   -54.4271  50.9
# 4          3.0          0.13       1.00   -2.1545   -54.4468  70.3

# %%
# Passo 5: Análise Mais completa
# comparar cada coluna da minha tabela com a coluna de cancelamento
import plotly.express as px

# etapa 1: criar o gráfico
for coluna in mp.columns:
    # para edições nos gráficos: https://plotly.com/python/histograms/
    # para mudar a cor do gráfico , color_discrete_sequence=["blue", "green"]
    grafico = px.histogram(mp, x="estado"	, color="riscofogo", text_auto=True)
    # etapa 2: exibir o gráfico
    grafico.show()
